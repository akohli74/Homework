# %%
import pandas as pd

# %%
employees = pd.read_csv('employee_data.csv')
employees.head()
# Out:
#    Emp ID              Name         DOB          SSN         State
# 0     232      John Mathews  1991-02-24  289-31-9165  North Dakota
# 1     533      Nathan Moore  1978-11-19  220-05-7469         Maine
# 2     256    Amanda Douglas  1990-01-08  564-27-6961         Idaho
# 3     189   Heather Andrews  1976-08-11  742-79-1797       Vermont
# 4     284  Daniel Hernandez  1976-07-22  656-01-7473      Colorado

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}
print(us_state_abbrev)
# Out:
# {'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA', 'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'}

# %%
employees[['First Name','Last Name']] = employees['Name'].loc[employees['Name'].str.split().str.len() == 2].str.split(expand=True)
employees.head()

employees.replace({"State": us_state_abbrev})
# Out:
#      Emp ID                Name         DOB          SSN State First Name  \
# 0       232        John Mathews  1991-02-24  289-31-9165    ND       John
# 1       533        Nathan Moore  1978-11-19  220-05-7469    ME     Nathan
# 2       256      Amanda Douglas  1990-01-08  564-27-6961    ID     Amanda
# 3       189     Heather Andrews  1976-08-11  742-79-1797    VT    Heather
# 4       284    Daniel Hernandez  1976-07-22  656-01-7473    CO     Daniel
# 5       512          Danny Pena  1978-01-31  158-33-9878    MN      Danny
# 6       126         Gary Knight  1994-03-08  782-25-1242    AR       Gary
# 7       556       Robin Carroll  1972-10-14  606-48-7194    CA      Robin
# 8       595  Michelle Dickerson  1984-02-08  707-24-2817    TN   Michelle
# 9       191   Kimberly Gallegos  1972-08-05  653-52-7563    OR   Kimberly
# 10       55       Morgan Parker  1986-01-30  692-70-4320    TN     Morgan
# 11      623        Mason Rhodes  1977-01-28  841-07-4767    MD      Mason
# ...
